# %%
# %matplotlib inline 
import seaborn as sns
import pandas as pd
import gmplot

# %%
df = pd.read_csv("datasets/2017_2018_descriptive_set.csv")
# Out:
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df["WAGE_RATE_OF_PAY_FROM"].hist(bins=1000, figsize=(20,10) , color = 'b')

# %%
sns.distplot(df["WAGE_RATE_OF_PAY_FROM"], bins=1000, hist=True, kde=True)

# %%
print("max: " + str(max(df["WAGE_RATE_OF_PAY_FROM"])) + " min: " +
str(min(df["WAGE_RATE_OF_PAY_FROM"])))
# Out:
# max: 2134381.0 min: 0.0

# %% [markdown]
# massive variation in wage being offered pay scales needs to be standardised as the wage given is in different levels

# %%
df["PW_UNIT_OF_PAY"].unique()
# Out:
# array(['Year', 'Hour', 'Month', 'Week', 'Bi-Weekly'], dtype=object)

# %%
sorted_df = df.sort_values("WAGE_RATE_OF_PAY_FROM", ascending=False)

# %%
sorted_df["WAGE_RATE_OF_PAY_FROM"]
# Out:
# 200463     2134381.00
# 264693     1900000.00
# 159859     1688000.00
# 714471     1688000.00
# 1081150    1500000.00
# 490427     1500000.00
# 302226     1350000.00
# 868414     1350000.00
# 289624     1300000.00
# 822405     1290000.00
# 690483     1250000.00
# 136356     1200000.00
# 311403     1100000.00
# 77597      1075000.00
# 813062     1075000.00
# 529441     1007475.00
# 134415     1000000.00
# 305043     1000000.00
# 625125     1000000.00
# 303747     1000000.00
# 109594      992250.00
# 67341       980000.00
# 532165      975000.00
# 753508      969970.00
# 609012      969000.00
# 862739      950000.00
# 875741      950000.00
# 18932       950000.00
# 818851      950000.00
# 891329      950000.00
#               ...
# 983520           8.00
# 911212           8.00
# 18682            8.00
# 408714           8.00
# 244388           8.00
# 1036698          8.00
# 1030990          8.00
# 615140           8.00
# 896799           8.00
# 1094429          8.00
# ...

# %%
sorted_df["WAGE_UNIT_OF_PAY"]
# Out:
# 200463     Year
# 264693     Year
# 159859     Year
# 714471     Year
# 1081150    Year
# 490427     Year
# 302226     Year
# 868414     Year
# 289624     Year
# 822405     Year
# 690483     Year
# 136356     Year
# 311403     Year
# 77597      Year
# 813062     Year
# 529441     Year
# 134415     Year
# 305043     Year
# 625125     Year
# 303747     Year
# 109594     Year
# 67341      Year
# 532165     Year
# 753508     Year
# 609012     Year
# 862739     Year
# 875741     Year
# 18932      Year
# 818851     Year
# 891329     Year
#            ...
# 983520     Hour
# 911212     Hour
# 18682      Hour
# 408714     Hour
# 244388     Hour
# 1036698    Hour
# 1030990    Hour
# 615140     Hour
# 896799     Hour
# 1094429    Hour
# 408503     Hour
# 49399      Hour
# 239242     Hour
# 907968     Hour
# 400233     Hour
# 302530     Hour
# 750570     Hour
# 849322     Hour
# 756025     Hour
# 750567     Hour
# 584756     Hour
# 977732     Hour
# 113805     Hour
# 171393     Hour
# ...

# %% [raw]
# build graph of a count of each type of wage unit.

# %%
sns.countplot(x="WAGE_UNIT_OF_PAY", data=df)

# %% [markdown]
# The majority of wgae type is yearly so the other types will be converted to yearly

# %%
df.loc[df.WAGE_UNIT_OF_PAY == "Week"]
# Out:
#         CASE_STATUS CASE_SUBMITTED DECISION_DATE      VISA_CLASS  \
# 8536      CERTIFIED     2017-10-03    2017-10-10            H-1B
# 15433        DENIED     2017-10-12    2017-10-16            H-1B
# 18953     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 19177     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 19223     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 19401     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 19403     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 19406     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 19407     CERTIFIED     2017-10-13    2017-10-19            H-1B
# 20691     CERTIFIED     2017-10-16    2017-10-20            H-1B
# 20959     CERTIFIED     2017-10-16    2017-10-20            H-1B
# 20971     CERTIFIED     2017-10-16    2017-10-20            H-1B
# 21404     CERTIFIED     2017-10-17    2017-10-23            H-1B
# ...

# %%
for i, row in df.iterrows():
    if row["WAGE_UNIT_OF_PAY"] == "Week":
        new_wage = df.at[i, "WAGE_RATE_OF_PAY_FROM"] * 52
        df.at[i,"WAGE_RATE_OF_PAY_FROM"] = new_wage
        
        new_wage = df.at[i, "PREVAILING_WAGE"] * 52
        df.at[i,"PREVAILING_WAGE"] = new_wage
        
        df.at[i,"WAGE_UNIT_OF_PAY"] = "Year"
        
    elif row["WAGE_UNIT_OF_PAY"] == "Hour":
        new_wage = (df.at[i, "WAGE_RATE_OF_PAY_FROM"] * 40) * 52
        df.at[i,"WAGE_RATE_OF_PAY_FROM"] = new_wage
        
        new_wage = (df.at[i, "PREVAILING_WAGE"] * 40) * 52
        df.at[i,"PREVAILING_WAGE"] = new_wage
        
        df.at[i,"WAGE_UNIT_OF_PAY"] = "Year"
        
    elif row["WAGE_UNIT_OF_PAY"] == "Bi-Weekly":
        new_wage = df.at[i, "WAGE_RATE_OF_PAY_FROM"] * 26
        df.at[i,"WAGE_RATE_OF_PAY_FROM"] = new_wage
        
        new_wage = df.at[i, "PREVAILING_WAGE"] * 26
        df.at[i,"PREVAILING_WAGE"] = new_wage
        
        df.at[i,"WAGE_UNIT_OF_PAY"] = "Year"
        
    elif row["WAGE_UNIT_OF_PAY"] == "Month":
        new_wage = df.at[i, "WAGE_RATE_OF_PAY_FROM"] * 12
        df.at[i,"WAGE_RATE_OF_PAY_FROM"] = new_wage
        
        new_wage = df.at[i, "PREVAILING_WAGE"] * 12
        df.at[i,"PREVAILING_WAGE"] = new_wage
        
        df.at[i,"WAGE_UNIT_OF_PAY"] = "Year"

# %% [markdown]
# going to estimate the average working week as 40 hours

# %%
df["WAGE_RATE_OF_PAY_FROM"].hist(bins=500, figsize=(20,10) , color = 'b')

# %%
df = df[df["WAGE_RATE_OF_PAY_FROM"] != 0.0]
print(df["WAGE_RATE_OF_PAY_FROM"])
# Out:
# 0           58032.00
# 1           95600.00
# 2           60400.00
# 3           65000.00
# 4           49383.00
# 5           45200.00
# 6           88381.32
# 7           53000.00
# 8           61347.00
# 9          104000.00
# 10         115000.00
# 11         110000.00
# 12          48610.00
# 13          89740.00
# 14          65000.00
# 15          50086.00
# 16          43000.00
# 17          50059.00
# 18          84843.00
# 19          62500.00
# 20          81120.00
# 21          49419.05
# 22         140000.00
# 23          47244.00
# 24          46000.00
# 25         160000.00
# 26         110074.00
# 27          54954.00
# 28          85000.00
# 29          60000.00
#              ...
# 1102266     72904.00
# 1102267    100000.00
# 1102268    105019.00
# 1102269    109200.00
# 1102270     66414.00
# 1102271     67558.00
# 1102272    130005.00
# 1102273    201468.80
# 1102274    125000.00
# 1102275     89301.00
# 1102276    120578.00
# 1102277     95000.00
# ...

# %%
test_df = df[df["WAGE_RATE_OF_PAY_FROM"] < 500000]

# %%
test_df["WAGE_RATE_OF_PAY_FROM"].hist(bins=500, figsize=(20,10) , color = 'b')

# %% [markdown]
# huge outliers in the proposed wage from the employeer the majority of wages are around 80,000 a year but some go near to 3.5 million

# %%
sns.set(style="whitegrid")
sns.distplot(test_df['WAGE_RATE_OF_PAY_FROM'],color='blue')
# Out:
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df["VISA_CLASS"].unique()
# Out:
# array(['H-1B', 'E-3 Australian', 'H-1B1 Singapore', 'H-1B1 Chile'],
#       dtype=object)

# %%
sns.countplot(x="VISA_CLASS", data=df)

# %% [markdown]
# We only want the entries which are H1-B and can see from trhe graph the entries which are not H1B represent a negliable portion of our data so we remove them

# %%
df = df[df["VISA_CLASS"] == "H-1B"]

# %%
sns.countplot(x="VISA_CLASS", data=df)

# %%
df.head(10)
# Out:
#   CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS EMPLOYMENT_START_DATE  \
# 0   CERTIFIED     2015-10-06    2017-10-01       H-1B            2015-11-15
# 1   CERTIFIED     2016-05-13    2017-10-01       H-1B            2016-09-01
# 2   CERTIFIED     2016-11-04    2017-10-01       H-1B            2016-12-01
# 3   CERTIFIED     2016-12-28    2017-10-01       H-1B            2017-02-01
# 4   CERTIFIED     2017-02-24    2017-10-01       H-1B            2017-06-01
# 5   CERTIFIED     2017-03-09    2017-10-01       H-1B            2017-09-08
# 6   CERTIFIED     2014-10-23    2017-10-02       H-1B            2014-11-01
# 7   CERTIFIED     2015-01-07    2017-10-02       H-1B            2015-02-01
# 8   CERTIFIED     2015-05-08    2017-10-02       H-1B            2015-10-01
# 9   CERTIFIED     2017-09-26    2017-10-02       H-1B            2017-10-10
#
#   EMPLOYMENT_END_DATE                                EMPLOYER_NAME  \
# ...

# %%
list(df)
# Out:
# ['CASE_STATUS',
#  'CASE_SUBMITTED',
#  'DECISION_DATE',
#  'VISA_CLASS',
#  'EMPLOYMENT_START_DATE',
#  'EMPLOYMENT_END_DATE',
#  'EMPLOYER_NAME',
#  'EMPLOYER_ADDRESS',
#  'EMPLOYER_CITY',
#  'EMPLOYER_STATE',
#  'EMPLOYER_POSTAL_CODE',
#  'JOB_TITLE',
#  'SOC_CODE',
#  'SOC_NAME',
#  'NAICS_CODE',
#  'TOTAL_WORKERS',
#  'NEW_EMPLOYMENT',
#  'CONTINUED_EMPLOYMENT',
#  'CHANGE_PREVIOUS_EMPLOYMENT',
#  'NEW_CONCURRENT_EMPLOYMENT',
#  'CHANGE_EMPLOYER',
#  'AMENDED_PETITION',
#  'FULL_TIME_POSITION',
#  'PREVAILING_WAGE',
#  'PW_UNIT_OF_PAY',
#  'PW_SOURCE',
#  'PW_SOURCE_YEAR',
#  'WAGE_RATE_OF_PAY_FROM',
#  'WAGE_RATE_OF_PAY_TO',
#  'WAGE_UNIT_OF_PAY',
#  'H1B_DEPENDENT',
#  'WILLFUL_VIOLATOR',
#  'WORKSITE_CITY',
#  'WORKSITE_COUNTY',
#  'WORKSITE_STATE',
#  'WORKSITE_POSTAL_CODE']

# %% [markdown]
# remove postal code county and city and all employer adress info and i will use the workplace state rather than employer

# %%
df = df.drop(["WORKSITE_CITY", "WORKSITE_COUNTY", "WORKSITE_POSTAL_CODE","EMPLOYER_ADDRESS",
              "EMPLOYER_CITY", "EMPLOYER_STATE", "EMPLOYER_POSTAL_CODE"], axis=1)

# %%
df= df.drop(["NAICS_CODE"], axis=1)

# %%
df["WORKSITE_STATE"].unique().size
# Out:
# 57

# %%
df["WORKSITE_STATE"].unique()
# Out:
# array(['MA', 'CA', 'MI', 'NY', 'MN', 'IL', 'TN', 'OR', 'WI', 'NJ', 'AZ',
#        'WA', 'OH', 'VA', 'TX', 'IN', 'PA', 'UT', 'CO', 'FL', 'LA', 'MO',
#        'GA', 'MS', 'DE', 'RI', 'IA', 'NH', 'MD', 'CT', 'MT', 'NV', 'SC',
#        'AR', 'NC', 'DC', 'KY', 'NM', 'KS', 'AL', 'NE', 'OK', 'ME', 'ID',
#        'ND', 'VT', 'HI', 'GU', 'VI', 'MP', 'WY', 'WV', 'AK', 'SD', 'PR',
#        'PW', 'FM'], dtype=object)

# %%
sns.set(style="whitegrid")
ax = sns.boxplot(x=df["WAGE_RATE_OF_PAY_FROM"])

# %%
ax = sns.boxplot(x=test_df["WAGE_RATE_OF_PAY_FROM"])

# %%
ax = sns.boxplot(x=df["PREVAILING_WAGE"])

# %%
ax = sns.boxplot(x=test_df["PREVAILING_WAGE"])

# %%
sorted_df["PREVAILING_WAGE"].mean()
# Out:
# 76033.61536025713

# %%
df["PREVAILING_WAGE"].mean()
# Out:
# 105022.282611979

# %%
test_df["WAGE_RATE_OF_PAY_FROM"].mean()
# Out:
# 90076.37321477628

# %%
df["WAGE_RATE_OF_PAY_FROM"].mean()
# Out:
# 95302.36099674631

# %% [markdown]
# We can see that the average offered wage is more than the prevailing wage and that the different in average wage between the data with outliers and the data without outliers is small

# %%
def create_wage_diff(row):
    return (row["WAGE_RATE_OF_PAY_FROM"] - row["PREVAILING_WAGE"])

# %%
df["wage_diff"] = df.apply(lambda row: create_wage_diff(row), axis=1)

# %%
df["wage_diff"].max()
# Out:
# 173222400.0

# %%
df["wage_diff"].min()
# Out:
# -389188800.0

# %%
df["PREVAILING_WAGE"].max()
# Out:
# 389376000.0

# %%
df[df["PREVAILING_WAGE"] == 201622735.0]
# Out:
#        CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 722434      DENIED     05/03/2017    07/03/2017       H-1B
#
#        EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE EMPLOYER_NAME  \
# 722434            26/08/2017          25/08/2020     WIPRO LLC
#
#                  JOB_TITLE SOC_CODE                         SOC_NAME  \
# 722434  CONSULTANT LEVEL 3  15-1199  COMPUTER OCCUPATIONS, ALL OTHER
#
#            ...       PW_UNIT_OF_PAY  PW_SOURCE  PW_SOURCE_YEAR  \
# 722434     ...                 Year        OES          2016.0
#
#         WAGE_RATE_OF_PAY_FROM  WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY  \
# 722434               124093.0                  0.0              Year
#
#         H1B_DEPENDENT WILLFUL_VIOLATOR  WORKSITE_STATE    wage_diff
# 722434              Y                N              CA -201498642.0
#
# [1 rows x 29 columns]

# %%
df["PREVAILING_WAGE"].hist(bins=500, figsize=(20,10) , color = 'b')

# %% [markdown]
# massive outliers in prevailing wage which is almost definitely a mistake as prevailing wage should be standard and the average for the type of job

# %%
test_df = df[df["PREVAILING_WAGE"] != 201622735.0]

# %%
test_df["PREVAILING_WAGE"].max()
# Out:
# 389376000.0

# %%
test_df["PREVAILING_WAGE"].hist(bins=500, figsize=(20,10) , color = 'b')

# %% [markdown]
# removing the one extreme outlier till i decide what to do about the rest

# %%
df = test_df
cut_off = df["WAGE_RATE_OF_PAY_FROM"].mean() + (2 * df["WAGE_RATE_OF_PAY_FROM"].std())
df = df[df["WAGE_RATE_OF_PAY_FROM"] < cut_off]
cut_off = df["PREVAILING_WAGE"].mean() + (2 * df["PREVAILING_WAGE"].std())
df = df[df["PREVAILING_WAGE"] < cut_off]
df["WAGE_RATE_OF_PAY_FROM"].hist(bins=500, figsize=(20,10) , color = 'b')

# %% [markdown]
# From looking at the histagrams i will chose to cut out any rows with a wage over 1 million

# %%
df["PREVAILING_WAGE"].hist(bins=500, figsize=(20,10) , color = 'b')

# %%
df = df[df["WAGE_RATE_OF_PAY_FROM"] < 1000000]
df = df[df["PREVAILING_WAGE"] < 1000000]

# %% [markdown]
# since we now have our 3 wage columns which we are interested in namely wage diff, wage from and prevailing we will remove all the rest

# %%
list(df)
# Out:
# ['CASE_STATUS',
#  'CASE_SUBMITTED',
#  'DECISION_DATE',
#  'VISA_CLASS',
#  'EMPLOYMENT_START_DATE',
#  'EMPLOYMENT_END_DATE',
#  'EMPLOYER_NAME',
#  'JOB_TITLE',
#  'SOC_CODE',
#  'SOC_NAME',
#  'TOTAL_WORKERS',
#  'NEW_EMPLOYMENT',
#  'CONTINUED_EMPLOYMENT',
#  'CHANGE_PREVIOUS_EMPLOYMENT',
#  'NEW_CONCURRENT_EMPLOYMENT',
#  'CHANGE_EMPLOYER',
#  'AMENDED_PETITION',
#  'FULL_TIME_POSITION',
#  'PREVAILING_WAGE',
#  'PW_UNIT_OF_PAY',
#  'PW_SOURCE',
#  'PW_SOURCE_YEAR',
#  'WAGE_RATE_OF_PAY_FROM',
#  'WAGE_RATE_OF_PAY_TO',
#  'WAGE_UNIT_OF_PAY',
#  'H1B_DEPENDENT',
#  'WILLFUL_VIOLATOR',
#  'WORKSITE_STATE',
#  'wage_diff']

# %%
df = df.drop(["PW_UNIT_OF_PAY", "PW_SOURCE", "PW_SOURCE_YEAR","WAGE_RATE_OF_PAY_TO",
              "WAGE_UNIT_OF_PAY"], axis=1)

# %%
df.to_csv("datasets/2017_2018_descriptive_set_initial_processed.csv", index=False)
