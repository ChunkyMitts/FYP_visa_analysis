# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("datasets/2017_2018_initial_processed.csv")
df.head(10)
# Out:
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            CASE_STATUS VISA_CLASS  \
# 0  CERTIFIED-WITHDRAWN       H-1B
# 1  CERTIFIED-WITHDRAWN       H-1B
# 2  CERTIFIED-WITHDRAWN       H-1B
# 3  CERTIFIED-WITHDRAWN       H-1B
# 4  CERTIFIED-WITHDRAWN       H-1B
# 5  CERTIFIED-WITHDRAWN       H-1B
# 6            WITHDRAWN       H-1B
# 7            WITHDRAWN       H-1B
# 8            WITHDRAWN       H-1B
# 9  CERTIFIED-WITHDRAWN       H-1B
#
#                                  EMPLOYER_NAME  \
# 0        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 1  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)
# 2        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 3        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 4        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 5          PARK VIEW TRAVEL BEVERLY HILLS, LLC
# 6                    IBM INDIA PRIVATE LIMITED
# 7                    IBM INDIA PRIVATE LIMITED
# 8                          BTREE SOLUTIONS INC
# 9              WALTER ASSOCIATES, INCORPORATED
#
#                     EMPLOYER_ADDRESS  EMPLOYER_CITY EMPLOYER_STATE  \
# 0            77 MASSACHUSETTS AVENUE      CAMBRIDGE             MA
# 1            77 MASSACHUSETTS AVENUE      CAMBRIDGE             MA
# 2            77 MASSACHUSETTS AVENUE      CAMBRIDGE             MA
# 3            77 MASSACHUSETTS AVENUE      CAMBRIDGE             MA
# 4            77 MASSACHUSETTS AVENUE      CAMBRIDGE             MA
# 5             9440 SANTA MONICA BLVD  BEVERLY HILLS             CA
# 6               3039 CORNWALLIS ROAD         DURHAM             NC
# 7               3039 CORNWALLIS ROAD         DURHAM             NC
# 8                570 HERNDON PARKWAY        HERNDON             VA
# 9  100 E. MICHIGAN AVENUE, SUITE 200         SALINE             MI
#
#   EMPLOYER_POSTAL_CODE AGENT_ATTORNEY_NAME                          JOB_TITLE  \
# 0                02139                   ,             POSTDOCTORAL ASSOCIATE
# 1                02139                   ,                ASSISTANT PROFESSOR
# 2                02139                   ,             POSTDOCTORAL ASSOCIATE
# 3                02139                   ,                 RESEARCH SCIENTIST
# 4                02139                   ,             POSTDOCTORAL ASSOCIATE
# 5                90210  CHUN-FRUTO, EILEEN  EVENTS AND INCENTIVES COORDINATOR
# 6                27709                   ,                   SENIOR DEVELOPER
# 7                27709                   ,           SENIOR SOFTWARE ENGINEER
# 8                20170                   ,           COMPUTER SYSTEMS ANALYST
# 9                48176      UBHI, ARVINDER                          ASSOCIATE
#
#   SOC_CODE         ...          PW_SOURCE_YEAR WAGE_RATE_OF_PAY_FROM  \
# 0  15-2041         ...                  2015.0              58032.00
# 1  25-1031         ...                  2016.0              95600.00
# 2  19-2012         ...                  2016.0              60400.00
# 3  19-2042         ...                  2016.0              65000.00
# 4  17-2131         ...                  2016.0              49383.00
# 5  13-1121         ...                  2016.0              45200.00
# 6  15-1131         ...                  2017.0              81837.00
# 7  15-1131         ...                  2017.0              81499.00
# 8  15-1121         ...                  2017.0              76000.00
# 9  15-1132         ...                  2014.0              88381.32
#
#    WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY  H1B_DEPENDENT  WILLFUL_VIOLATOR  \
# 0                  0.0              Year              N                 N
# 1                  0.0              Year              N                 N
# 2                  0.0              Year              N                 N
# 3                  0.0              Year              N                 N
# 4                  0.0              Year              N                 N
# 5                  0.0              Year              N                 N
# 6                  0.0              Year              N                 N
# 7                  0.0              Year              N                 N
# 8                  0.0              Year              Y                 N
# 9                  0.0              Year              N                 N
#
#         WORKSITE_CITY   WORKSITE_COUNTY  WORKSITE_STATE WORKSITE_POSTAL_CODE
# 0           CAMBRIDGE         MIDDLESEX              MA                02139
# 1           CAMBRIDGE  MIDDLESEX COUNTY              MA                02139
# 2           CAMBRIDGE         MIDDLESEX              MA                02139
# 3           CAMBRIDGE         MIDDLESEX              MA                02139
# 4           CAMBRIDGE         MIDDLESEX              MA                02139
# 5       BEVERLY HILLS       LOS ANGELES              CA                90210
# 6       DOWNERS GROVE            DUPAGE              IL                60515
# 7  WHITEHOUSE STATION         HUNTERDON              NJ                08889
# 8            COLUMBUS          FRANKLIN              OH                43214
# 9              SALINE         WASHTENAW              MI               480176
#
# [10 rows x 33 columns]

# %%
df["CASE_STATUS"].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED'],
#       dtype=object)

# %%
df = df[df["CASE_STATUS"] != 'WITHDRAWN']

# %%
df["CASE_STATUS"].replace('CERTIFIED-WITHDRAWN', 'CERTIFIED', inplace=True)

# %% [markdown]
# Agent attorney name seems to be filled with , to avoid na values

# %%
df_agent = df[df["AGENT_ATTORNEY_NAME"] == ","]
df_agent["AGENT_ATTORNEY_NAME"].count()
# Out:
# 408455

# %%
df = df.drop(["AGENT_ATTORNEY_NAME"], axis=1)

# %%
df.corr()
# Out:
#                             TOTAL_WORKERS  NEW_EMPLOYMENT  \
# TOTAL_WORKERS                    1.000000        0.776024
# NEW_EMPLOYMENT                   0.776024        1.000000
# CONTINUED_EMPLOYMENT             0.429969        0.033084
# CHANGE_PREVIOUS_EMPLOYMENT       0.310912        0.015999
# NEW_CONCURRENT_EMPLOYMENT        0.110236        0.021940
# CHANGE_EMPLOYER                  0.402492        0.031119
# AMENDED_PETITION                 0.420653        0.025609
# PREVAILING_WAGE                  0.005485       -0.000683
# PW_SOURCE_YEAR                   0.001999        0.000448
# WAGE_RATE_OF_PAY_FROM            0.001193       -0.026551
# WAGE_RATE_OF_PAY_TO              0.127073        0.075571
#
#                             CONTINUED_EMPLOYMENT  CHANGE_PREVIOUS_EMPLOYMENT  \
# TOTAL_WORKERS                           0.429969                    0.310912
# NEW_EMPLOYMENT                          0.033084                    0.015999
# CONTINUED_EMPLOYMENT                    1.000000                    0.094878
# CHANGE_PREVIOUS_EMPLOYMENT              0.094878                    1.000000
# NEW_CONCURRENT_EMPLOYMENT               0.072999                    0.109160
# CHANGE_EMPLOYER                         0.176272                    0.156432
# AMENDED_PETITION                        0.150729                    0.101484
# PREVAILING_WAGE                         0.006879                    0.004191
# PW_SOURCE_YEAR                          0.001244                    0.002024
# WAGE_RATE_OF_PAY_FROM                   0.026357                    0.011904
# WAGE_RATE_OF_PAY_TO                     0.056440                    0.090575
#
#                             NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  \
# TOTAL_WORKERS                                0.110236         0.402492
# NEW_EMPLOYMENT                               0.021940         0.031119
# CONTINUED_EMPLOYMENT                         0.072999         0.176272
# CHANGE_PREVIOUS_EMPLOYMENT                   0.109160         0.156432
# NEW_CONCURRENT_EMPLOYMENT                    1.000000         0.072857
# CHANGE_EMPLOYER                              0.072857         1.000000
# AMENDED_PETITION                             0.045645         0.172777
# PREVAILING_WAGE                             -0.011162         0.010230
# PW_SOURCE_YEAR                               0.003564         0.002496
# WAGE_RATE_OF_PAY_FROM                       -0.061775         0.046781
# WAGE_RATE_OF_PAY_TO                          0.026163         0.067335
#
#                             AMENDED_PETITION  PREVAILING_WAGE  PW_SOURCE_YEAR  \
# TOTAL_WORKERS                       0.420653         0.005485        0.001999
# NEW_EMPLOYMENT                      0.025609        -0.000683        0.000448
# CONTINUED_EMPLOYMENT                0.150729         0.006879        0.001244
# CHANGE_PREVIOUS_EMPLOYMENT          0.101484         0.004191        0.002024
# NEW_CONCURRENT_EMPLOYMENT           0.045645        -0.011162        0.003564
# CHANGE_EMPLOYER                     0.172777         0.010230        0.002496
# AMENDED_PETITION                    1.000000         0.003065        0.000491
# PREVAILING_WAGE                     0.003065         1.000000        0.002186
# PW_SOURCE_YEAR                      0.000491         0.002186        1.000000
# WAGE_RATE_OF_PAY_FROM               0.004084         0.148728        0.007017
# WAGE_RATE_OF_PAY_TO                 0.060219         0.045769       -0.002478
#
#                             WAGE_RATE_OF_PAY_FROM  WAGE_RATE_OF_PAY_TO
# TOTAL_WORKERS                            0.001193             0.127073
# NEW_EMPLOYMENT                          -0.026551             0.075571
# CONTINUED_EMPLOYMENT                     0.026357             0.056440
# CHANGE_PREVIOUS_EMPLOYMENT               0.011904             0.090575
# NEW_CONCURRENT_EMPLOYMENT               -0.061775             0.026163
# CHANGE_EMPLOYER                          0.046781             0.067335
# AMENDED_PETITION                         0.004084             0.060219
# PREVAILING_WAGE                          0.148728             0.045769
# PW_SOURCE_YEAR                           0.007017            -0.002478
# WAGE_RATE_OF_PAY_FROM                    1.000000             0.205263
# WAGE_RATE_OF_PAY_TO                      0.205263             1.000000

# %%
df.dtypes
# Out:
# CASE_STATUS                    object
# VISA_CLASS                     object
# EMPLOYER_NAME                  object
# EMPLOYER_ADDRESS               object
# EMPLOYER_CITY                  object
# EMPLOYER_STATE                 object
# EMPLOYER_POSTAL_CODE           object
# JOB_TITLE                      object
# SOC_CODE                       object
# SOC_NAME                       object
# NAICS_CODE                     object
# TOTAL_WORKERS                   int64
# NEW_EMPLOYMENT                  int64
# CONTINUED_EMPLOYMENT            int64
# CHANGE_PREVIOUS_EMPLOYMENT      int64
# NEW_CONCURRENT_EMPLOYMENT       int64
# CHANGE_EMPLOYER                 int64
# AMENDED_PETITION                int64
# FULL_TIME_POSITION             object
# PREVAILING_WAGE               float64
# PW_UNIT_OF_PAY                 object
# PW_SOURCE                      object
# PW_SOURCE_YEAR                float64
# WAGE_RATE_OF_PAY_FROM         float64
# WAGE_RATE_OF_PAY_TO           float64
# WAGE_UNIT_OF_PAY               object
# H1B_DEPENDENT                  object
# WILLFUL_VIOLATOR               object
# WORKSITE_CITY                  object
# WORKSITE_COUNTY                object
# WORKSITE_STATE                 object
# WORKSITE_POSTAL_CODE           object
# dtype: object

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
pca.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c08257722399> in <module>()
# ----> 1 pca.fit(df)
#
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\sklearn\decomposition\pca.py in fit(self, X, y)
#     338             Returns the instance itself.
#     339         """
# --> 340         self._fit(X)
#     341         return self
#     342
#
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     379
#     380         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 381                         copy=self.copy)
#     382
#     383         # Handle n_components==None
#
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     520             try:
#     521                 warnings.simplefilter('error', ComplexWarning)
# --> 522                 array = np.asarray(array, dtype=dtype, order=order)
#     523             except ComplexWarning:
#     524                 raise ValueError("Complex data not supported\n"
#
# c:\users\aidan\appdata\local\programs\python\python37\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: could not convert string to float: '95054-1214'
