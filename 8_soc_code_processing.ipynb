# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import pandas as pd
df = pd.read_csv("datasets/2017_2018_preprocessing3.csv")

# %%
df.head()
# Out:
#   CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS EMPLOYMENT_START_DATE  \
# 0   CERTIFIED     2015-10-06    2017-10-01       H-1B            2015-11-15
# 1   CERTIFIED     2016-05-13    2017-10-01       H-1B            2016-09-01
# 2   CERTIFIED     2016-11-04    2017-10-01       H-1B            2016-12-01
# 3   CERTIFIED     2016-12-28    2017-10-01       H-1B            2017-02-01
# 4   CERTIFIED     2017-02-24    2017-10-01       H-1B            2017-06-01
#
#   EMPLOYMENT_END_DATE                                EMPLOYER_NAME  \
# 0          2017-11-14        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 1          2019-08-31  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)
# 2          2017-11-30        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 3          2018-01-31        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 4          2018-05-31        MASSACHUSETTS INSTITUTE OF TECHNOLOGY
#
#                 JOB_TITLE SOC_CODE  \
# 0  POSTDOCTORAL ASSOCIATE  15-2041
# 1     ASSISTANT PROFESSOR  25-1031
# 2  POSTDOCTORAL ASSOCIATE  19-2012
# 3      RESEARCH SCIENTIST  19-2042
# 4  POSTDOCTORAL ASSOCIATE  17-2131
#
#                                             SOC_NAME         ...           \
# 0                                      STATISTICIANS         ...
# 1               ARCHITECTURE TEACHERS, POSTSECONDARY         ...
# 2                                         PHYSICISTS         ...
# 3  GEOSCIENTISTS, EXCEPT HYDROLOGISTS AND GEOGRAP...         ...
# 4                                MATERIALS ENGINEERS         ...
#
#    FULL_TIME_POSITION  PREVAILING_WAGE  WAGE_RATE_OF_PAY_FROM  WORKSITE_STATE  \
# 0                   Y          58032.0                58032.0              MA
# 1                   Y          60967.0                95600.0              MA
# 2                   Y          50398.0                60400.0              MA
# 3                   Y          61069.0                65000.0              MA
# 4                   Y          41392.0                49383.0              MA
#
#    wage_diff    regions  applications_per_employer employer_success_rate  \
# 0        0.0  northeast                        362                  98.6
# 1    34633.0  northeast                         50                  96.0
# 2    10002.0  northeast                        362                  98.6
# 3     3931.0  northeast                        362                  98.6
# 4     7991.0  northeast                        362                  98.6
#
#    decision_duration  employment_duration
# 0                726                  730
# 1                506                 1094
# 2                331                  364
# 3                277                  364
# 4                219                  364
#
# [5 rows x 27 columns]

# %%
list(df)
# Out:
# ['CASE_STATUS',
#  'CASE_SUBMITTED',
#  'DECISION_DATE',
#  'VISA_CLASS',
#  'EMPLOYMENT_START_DATE',
#  'EMPLOYMENT_END_DATE',
#  'EMPLOYER_NAME',
#  'JOB_TITLE',
#  'SOC_CODE',
#  'SOC_NAME',
#  'TOTAL_WORKERS',
#  'NEW_EMPLOYMENT',
#  'CONTINUED_EMPLOYMENT',
#  'CHANGE_PREVIOUS_EMPLOYMENT',
#  'NEW_CONCURRENT_EMPLOYMENT',
#  'CHANGE_EMPLOYER',
#  'AMENDED_PETITION',
#  'FULL_TIME_POSITION',
#  'PREVAILING_WAGE',
#  'WAGE_RATE_OF_PAY_FROM',
#  'WORKSITE_STATE',
#  'wage_diff',
#  'regions',
#  'applications_per_employer',
#  'employer_success_rate',
#  'decision_duration',
#  'employment_duration']

# %%
df["SOC_CODE"].value_counts()
# Out:
# 15-1132                     271226
# 15-1121                     165418
# 15-1199                     107398
# 15-1131                      86170
# 15-1133                      38612
# 13-1111                      23111
# 15-2031                      20027
# 13-2011                      19863
# 15-1142                      18872
# 17-2141                      18262
# 13-2051                      16743
# 15-1141                      15496
# 17-2071                      12311
# 13-1161                      12289
# 17-2072                      11851
# 15-2041                      11220
# 29-1069                      10908
# Nov-21                        9721
# 15-1134                       8764
# 19-1042                       8299
# 17-2112                       7158
# 17-2051                       6806
# 17-2199                       6347
# 11-3021                       6120
# 19-1029                       6079
# 19-1021                       5345
# 29-1123                       5029
# 13-2099                       4912
# 15-1122                       4575
# 41-9031                       4178
#                              ...
# 31084                            1
# 37964                            1
# 11-9199.06                       1
# 15-1032                          1
# 25-1126.00                       1
# 21-1091.00                       1
# 19-2011.00                       1
# 41-9041                          1
# 43-3051                          1
# 27-4012                          1
# 13-1199.05                       1
# 17-2199.99                       1
# 74204                            1
# 49-2093                          1
# 152041                           1
# 41-9011                          1
# 17.2199.02                       1
# 151133                           1
# 15.1199.09                       1
# 13-2013                          1
# 51-4121                          1
# 37-1011                          1
# ACCOUNTANTS AND AUDITORS         1
# 25-1063.00                       1
# 15.1141                          1
# 13-1078                          1
# 45300                            1
# 51-7042                          1
# ELECTRICAL ENGINEERS             1
# 53-1021                          1
# Name: SOC_CODE, Length: 838, dtype: int64

# %%
df["SOC_CODE"].unique().size
# Out:
# 838

# %%
df["SOC_NAME"].unique().size
# Out:
# 1038
